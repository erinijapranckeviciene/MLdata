# %% [markdown]
# <a href="https://colab.research.google.com/github/erinijapranckeviciene/MLdata/blob/main/Blobs_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Synthetic data blobs - Multivariate normal

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

n_samples = 1500
random_state = 170
# standard deviation controls spread of points around the centroids 
c_std=[1,1]
X, y = make_blobs(n_samples=n_samples, random_state=random_state, centers=2,n_features=2,cluster_std=c_std)

# %%
# y contains class labels of the blobs
print(y)
# Out:
# [1 1 0 ... 1 1 0]

# %%
plt.figure(figsize=(12, 12))
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.title("Synthetic Blobs")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No handles with labels found to put in legend.
